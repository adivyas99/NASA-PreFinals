# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as plot
import datetime

# %%
data = pd.read_csv('data2.csv')

# %%
data.shape
# Out:
# (202, 10)

# %%
data.head()
# Out:
#            Designation Discovery Date YYYY-MM-DD  H (mag)  MOID (AU)  q (AU)  \
# 0   419880 (2011 AH37)                01/07/2011     19.7      0.035    0.84
# 1   419624 (2010 SO16)                09/17/2010     20.5      0.028    0.93
# 2  414772 (2010 OC103)                07/28/2010     19.0      0.333    0.39
# 3   414746 (2010 EH20)                03/06/2010     18.0      0.268    1.25
# 4  407324 (2010 OB101)                07/18/2010     20.7      0.111    0.77
#
#    Q (AU)  period (yr)  i (deg) PHA Orbit Class
# 0    4.26         4.06     9.65   Y      Apollo
# 1    1.08         1.00    14.52   Y      Apollo
# 2    2.00         1.31    23.11   N      Apollo
# 3    3.99         4.24    23.89   N        Amor
# 4    2.46         2.06     9.12   N      Apollo

# %%
data.columns
# Out:
# Index(['Designation', 'Discovery Date YYYY-MM-DD', 'H (mag)', 'MOID (AU)',
#        'q (AU)', 'Q (AU)', 'period (yr)', 'i (deg)', 'PHA', 'Orbit Class'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# Designation                   0
# Discovery Date YYYY-MM-DD     0
# H (mag)                      21
# MOID (AU)                     0
# q (AU)                        0
# Q (AU)                        2
# period (yr)                   2
# i (deg)                       0
# PHA                          21
# Orbit Class                   0
# dtype: int64

# %%
data = data.set_index('Discovery Date YYYY-MM-DD')
data.head(3)
# Out:
#                                    Designation  H (mag)  MOID (AU)  q (AU)  \
# Discovery Date YYYY-MM-DD
# 01/07/2011                  419880 (2011 AH37)     19.7      0.035    0.84
# 09/17/2010                  419624 (2010 SO16)     20.5      0.028    0.93
# 07/28/2010                 414772 (2010 OC103)     19.0      0.333    0.39
#
#                            Q (AU)  period (yr)  i (deg) PHA Orbit Class
# Discovery Date YYYY-MM-DD
# 01/07/2011                   4.26         4.06     9.65   Y      Apollo
# 09/17/2010                   1.08         1.00    14.52   Y      Apollo
# 07/28/2010                   2.00         1.31    23.11   N      Apollo

# %%
data['MOID (AU)'].plot()
fig = data['MOID (AU)'].plot(figsize=(12,5)).get_figure()
fig.savefig("myplot3.pdf")

# %%
data.PHA.value_counts().plot(kind='bar')
fig = data['MOID (AU)'].plot(figsize=(12,5)).get_figure()
fig.savefig("myplot4.pdf")

# %%
data['Orbit Class'].value_counts().plot(\='bar')
fig = data['Orbit Class'].value_counts().plot(figsize=(12,5)).get_figure()
fig.savefig("myplot3.pdf")

# %%
sns.countplot(x = 'Orbit Class', data = data, orient='h', hue = 'PHA')

# %% [raw]
# import sklearn.impute.SimpleImputer as ipt
# ipt

# %%
data['q (AU)'].plot()

# %%
plt.savefig('foo.png')
