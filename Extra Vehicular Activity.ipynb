# %% [markdown]
# # Deep into Extra vehicular activity
# ## Performed by US & Canada

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as plot
import datetime

# %%
data = pd.read_csv('data.csv')

# %%
data.shape
# Out:
# (375, 7)

# %%
data.head()
# Out:
#    EVA # Country       Crew          Vehicle        Date Duration  \
# 0    1.0     USA       Ed White    Gemini IV  06/03/1965     0:36
# 1    2.0     USA    David Scott  Gemini VIII         NaN     0:00
# 2    3.0     USA  Eugene Cernan  Gemini IX-A  06/05/1966     2:07
# 3    4.0     USA   Mike Collins     Gemini X  07/19/1966     0:50
# 4    5.0     USA   Mike Collins     Gemini X  07/20/1966     0:39
#
#                                             Purpose
# 0  First U.S. EVA. Used HHMU and took  photos.  G...
# 1  HHMU EVA cancelled before starting by stuck on...
# 2  Inadequate restraints, stiff 25ft umbilical an...
# 3  Standup EVA.  UV photos of stars.  Ended by ey...
# 4  Retrieved MMOD experiment from docked Agena.  ...

# %%
data.columns
# Out:
# Index(['EVA #', 'Country', 'Crew    ', 'Vehicle', 'Date', 'Duration',
#        'Purpose '],
#       dtype='object')

# %%
s = data.Country.value_counts()

# %%
explode = (0, 0.06)
fig1, ax1 = plt.subplots()
ax1.pie(s, labels = ['USA', 'Russia'], explode = explode, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal') 
plt.show()

# %% [raw]
# data.Vehicle.count().plot(kind = 'bar')

# %%
ax = data['Vehicle'].value_counts().plot(kind='bar',
                                    figsize=(16,8),
                                    title="Vehicle counts!")
ax.set_xlabel("Vehicles")
ax.set_ylabel("Count")
plt.show()

# %%
ax = data['Crew    '].value_counts().plot(kind='bar',
                                    figsize=(16,8),
                                    title="Vehicle counts!")
ax.set_xlabel("Vehicles")
ax.set_ylabel("Count")
plt.show()

# %%
data.isna().sum()
# Out:
# EVA #        4
# Country      0
# Crew         0
# Vehicle      1
# Date        44
# Duration     1
# Purpose      4
# dtype: int64

# %%
print (data['Duration'].total_seconds())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-ece3cedc572c> in <module>
# ----> 1 print (data['Duration'].total_seconds())
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'total_seconds'

# %%
data['Duration'] = data.Duration.astype(str)

# %%
data
# Out:
#      EVA # Country                                           Crew      \
# 0      1.0     USA                                           Ed White
# 1      2.0     USA                                        David Scott
# 2      3.0     USA                                      Eugene Cernan
# 3      4.0     USA                                       Mike Collins
# 4      5.0     USA                                       Mike Collins
# ..     ...     ...                                                ...
# 370  367.0  Russia                 Gennady Padalka  Yuri Malenchenko
# 371  368.0  Russia               Pavel Vinogradov     Roman Romanenko
# 372  369.0  Russia  Fyodor Yurchikhin                  Alexander M...
# 373  370.0  Russia  Fyodor Yurchikhin                  Alexander M...
# 374  371.0  Russia  Fyodor Yurchikhin                  Alexander M...
#
#          Vehicle        Date Duration  \
# 0      Gemini IV  06/03/1965     0:36
# 1    Gemini VIII         NaN     0:00
# ...

# %%
def toSeconds(x):
    h,m,s = x.split(':')
    print(int(datetime.timedelta(hours=0,minutes=int(m),seconds=int(s)).total_seconds()))

# %%
data['Duration'] = data.Duration.map(toSeconds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-d9898f28f1aa> in <module>
# ----> 1 data['Duration'] = data.Duration.map(toSeconds)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3823         dtype: object
#    3824         """
# -> 3825         new_values = super()._map_values(arg, na_action=na_action)
#    3826         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3827
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1298
#    1299         # mapper is a function
# -> 1300         new_values = map_f(values, mapper)
#    1301
#    1302         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-80-2de246b82d65> in toSeconds(x)
#       1 def toSeconds(x):
# ...

# %%
data.dtypes
# Out:
# EVA #       float64
# Country      object
# Crew         object
# Vehicle      object
# Date         object
# Duration     object
# Purpose      object
# dtype: object

# %%
data.Duration[1].split(':')
# Out:
# ['0', '00']

# %%
for i in data.Duration:
